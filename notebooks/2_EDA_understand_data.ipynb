# %% [markdown]
# <h1 style='color:crimson'>EDA: House Info and Missing Value's Analysis<h1>
#
# ![](data:image/jpeg;base64,...)

# %% [markdown]
# ### Import Required Libraries

# %%
import pandas as pd
import psycopg2
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %% [markdown]
#  ### Load the data into Panda's DataFrame

# %%
df_houses = pd.read_csv("../data/king_country_house_data_index_false.csv")
combined = pd.concat([df_houses.head(), df_houses.tail()])
combined
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520       3.0       1.00       1180.0    5650.0     1.0
# 1      6414100192       3.0       2.25       2570.0    7242.0     2.0
# 2      5631500400       2.0       1.00        770.0   10000.0     1.0
# 3      2487200875       4.0       3.00       1960.0    5000.0     1.0
# 4      1954400510       3.0       2.00       1680.0    8080.0     1.0
# 21592   263000018       3.0       2.50       1530.0    1131.0     3.0
# 21593  6600060120       4.0       2.50       2310.0    5813.0     2.0
# 21594  1523300141       2.0       0.75       1020.0    1350.0     2.0
# 21595   291310100       3.0       2.50       1600.0    2388.0     2.0
# 21596  1523300157       2.0       0.75       1020.0    1076.0     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 0             NaN   0.0          3      7  ...            0.0      1955
# ...

# %% [markdown]
# ### Examine the descriptive statistics of the dataset.

# %%
# Basic descriptive statistics for numerical columns
df_houses.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   4.580474e+09      3.373200      2.115826   2080.321850  1.509941e+04
# std    2.876736e+09      0.926299      0.768984    918.106125  4.141264e+04
# min    1.000102e+06      1.000000      0.500000    370.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    3.904930e+09      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    7.308900e+09      4.000000      2.500000   2550.000000  1.068500e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21597.000000  19206.000000  21534.000000  21597.000000  21597.000000
# mean       1.494096      0.007602      0.233863      3.409825      7.657915
# ...

# %%
# Include all columns (numerical + categorical):
df_houses.describe(include='all')
# Out:
#                   id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count   2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    4.580474e+09      3.373200      2.115826   2080.321850  1.509941e+04
# std     2.876736e+09      0.926299      0.768984    918.106125  4.141264e+04
# min     1.000102e+06      1.000000      0.500000    370.000000  5.200000e+02
# 25%     2.123049e+09      3.000000      1.750000   1430.000000  5.040000e+03
# 50%     3.904930e+09      3.000000      2.250000   1910.000000  7.618000e+03
# 75%     7.308900e+09      4.000000      2.500000   2550.000000  1.068500e+04
# max     9.900000e+09     33.000000      8.000000  13540.000000  1.651359e+06
#
# ...

# %%
# Check for missing values
df_houses.isnull().sum()
# Out:
# id                  0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2391
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement     452
# yr_built            0
# yr_renovated     3848
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# date                0
# price               0
# dtype: int64

# %%
# Show column data types
df_houses.dtypes

# Summary of dataframe shape and non-null counts
df_houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   bedrooms       21597 non-null  float64
#  2   bathrooms      21597 non-null  float64
#  3   sqft_living    21597 non-null  float64
#  4   sqft_lot       21597 non-null  float64
#  5   floors         21597 non-null  float64
#  6   waterfront     19206 non-null  float64
#  7   view           21534 non-null  float64
#  8   condition      21597 non-null  int64
#  9   grade          21597 non-null  int64
#  10  sqft_above     21597 non-null  float64
#  11  sqft_basement  21145 non-null  float64
#  12  yr_built       21597 non-null  int64
#  13  yr_renovated   17749 non-null  float64
#  14  zipcode        21597 non-null  int64
#  15  lat            21597 non-null  float64
#  16  long           21597 non-null  float64
# ...

# %% [markdown]
# ### Check for missing values

# %%
# Check total missing values per column
missing_per_column = df_houses.isnull().sum()

# Show percentage of missing values per column
missing_percentage = (df_houses.isnull().mean() * 100).sort_values(ascending=False)

# Display columns with missing values
print("Missing values per column:\n", missing_per_column[missing_per_column > 0])
print("\nPercentage of missing values per column:\n", missing_percentage[missing_percentage > 0])

# Optional: Visualize missing values with a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.heatmap(df_houses.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()
# Out:
# Missing values per column:
#  waterfront       2391
# view               63
# sqft_basement     452
# yr_renovated     3848
# dtype: int64
#
# Percentage of missing values per column:
#  yr_renovated     17.817289
# waterfront       11.070982
# sqft_basement     2.092883
# view              0.291707
# dtype: float64

# %% [markdown]
# ### Check which features are continuous or categorical.

# %%
# Check the data types of each column
data_types = df_houses.dtypes

# Categorical features typically have 'object', 'category', or 'bool' data types
categorical_features = df_houses.select_dtypes(include=['object', 'category', 'bool']).columns

# Continuous features are typically numeric (int, float)
continuous_features = df_houses.select_dtypes(include=['int64', 'float64']).columns

# Display the features
print("Categorical Features:\n", categorical_features)
print("\nContinuous Features:\n", continuous_features)
# Out:
# Categorical Features:
#  Index(['date'], dtype='object')
#
# Continuous Features:
#  Index(['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')
